# %% [markdown]
# # Creating college_names Table

# %%
# import dependencies
import os
import pandas as pd
from sqlalchemy import create_engine

# %%
# set up display area to show dataframe in jupyter qtconsole
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1248)

# %%
# create a connection to the database
engine = create_engine('postgresql://postgres:postgres@localhost:5432/HigherEducation')
con = engine.connect()

# %%
# read the datadictionary on the third sheet from excel file
datadict = pd.read_excel('CollegeScorecardDataDictionary.xlsx', sheet_name=3)

# %%
# retrieve datadictionary information for degrees
deg_cols = datadict[(datadict['dev-category']=='academics') &  (datadict['VARIABLE NAME'].str.contains('PCIP'))]

# %% [markdown]
# ### College Scorecard Data Dictionary of Interest

# %%
HIGHDEG = {
	0:	'Non-degree-granting',
	1:	'Certificate degree',
	2:	'Associate degree',
	3:	'Bachelors degree',
	4:	'Graduate degree'
}

ICLEVEL = {
	1:	'4-year',
	2:	'2-year',
	3:	'Less-than-2-year'
}

REGION = {
	0:	'U.S. Service Schools',
	1:	'New England (CT, ME, MA, NH, RI, VT)',
	2:	'Mid East (DE, DC, MD, NJ, NY, PA)',
	3:	'Great Lakes (IL, IN, MI, OH, WI)',
	4:	'Plains (IA, KS, MN, MO, NE, ND, SD)',
	5:	'Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC, TN, VA, WV)',
	6:	'Southwest (AZ, NM, OK, TX)',
	7:	'Rocky Mountains (CO, ID, MT, UT, WY)',
	8:	'Far West (AK, CA, HI, NV, OR, WA)',
	9:	'Outlying Areas (AS, FM, GU, MH, MP, PR, PW, VI)'
}

DISTANCEONLY = {
	0:	'Not distance-education only',
	1:	'Distance-education only'
}
    
CURROPER = {
	0:	'Not currently certified as an operating institution',
	1:	'Currently certified as operating'
}
    
SCHTYPE = { 
	1:	'Public',
	2:	'Private, Nonprofit',
	3:	'Private, For-profit'
}

# %% [markdown]
# ## Create college_names dataframe
# ### read all CSV files into a pandas dataframe in which the year is the key for the dataframe

# %%
# get current working directory
file_path = os.getcwd()

# create an empty dataframe for storing the CSV files data
college_names_df = pd.DataFrame() 

# loop through files in current directory
for filename in os.listdir(file_path):
    if 'MERGED' in filename:
        year = filename[6:][:7]
        df = pd.read_csv(os.path.join(file_path, filename), encoding='utf-8', low_memory=False)
        df = df[['UNITID','INSTNM','INSTURL',\
                 'CITY','STABBR','ZIP',\
                 'LATITUDE','LONGITUDE',\
                 'REGION','SCHTYPE',\
                 'HIGHDEG','CURROPER'
                 ]]
        #df['YEAR'] = int(year)
        try:
            college_names_df = college_names_df.append(df, ignore_index=True)
        except:
            print('CSV dataframe append failed')
            
# keep only the first 5 characters of the zip code
college_names_df['ZIP'] = college_names_df['ZIP'].str[:5]

cond1 = (college_names_df['CURROPER'] == 1)           # select currently operating schools
cond2 = (college_names_df['HIGHDEG'] > 0)             # select degree granting schools only
college_names_df = college_names_df[cond1 & cond2]    # filter data and save as updated dataframe

# rename columns
college_names_df = college_names_df.rename(columns={
                                                        'UNITID'    : 'college_id',
                                                        'INSTNM'    : 'name',
                                                        'INSTURL'   : 'website',
                                                        'SCHTYPE'   : 'schtype',
                                                        'CITY'      : 'city',
                                                        'STABBR'    : 'state',
                                                        'ZIP'       : 'zipcode',
                                                        'LATITUDE'  : 'latitude',
                                                        'LONGITUDE' : 'longitude',
                                                        'REGION'    : 'region'
                                                    })

# drop last two rows
df_cols = len(college_names_df.columns)
college_names_df.drop(college_names_df.iloc[:, df_cols-2:df_cols], inplace = True, axis = 1)

# update region names using the data dictionary provided by College Scorecard
college_names_df['region'] = college_names_df['region'].replace(REGION)
college_names_df['schtype'] = college_names_df['schtype'].replace(SCHTYPE)

print(college_names_df.shape)
college_names_df.head(2)
# Out:
# (6127, 10)
#    college_id                                 name        website        city  \
# 0      100654             Alabama A & M University  www.aamu.edu/      Normal
# 1      100663  University of Alabama at Birmingham    www.uab.edu  Birmingham
#
#   state zipcode   latitude  longitude  \
# 0    AL   35762  34.783368 -86.568502
# 1    AL   35294  33.505697 -86.799345
#
#                                               region schtype
# 0  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...  Public
# 1  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...  Public

# %% [markdown]
# ### Import CSVs from Kaggle with Schools Listed

# %%
schools_df = pd.read_csv('../kaggle/salaries-by-region-id.csv', encoding='utf-8').iloc[:, 0:2]

# drop any rows with a missing college id
schools_df = schools_df[schools_df['UNITID'].isna() == False]

# convert the college id to an integer
schools_df = schools_df.astype({ 'UNITID': int })

# rename the `UNITID` column to `college_id`
schools_df.rename(columns={'UNITID': 'college_id', 'School Name': 'name'}, inplace=True)

# drop duplicates
schools_df.drop_duplicates(inplace=True)

# sort `college_id`
schools_df.sort_values(by='college_id', inplace=True)

# reset index
schools_df.reset_index(drop=True, inplace=True)

# set `college_id` as the index
#schools_df.set_index('college_id', inplace=True)

print(schools_df.shape)
schools_df.head()
# Out:
# (317, 2)
#    college_id                                       name
# 0      100663  University of Alabama at Birmingham (UAB)
# 1      100706  University of Alabama at Huntsville (UAH)
# 2      100751          University of Alabama, Tuscaloosa
# 3      100858                          Auburn University
# 4      102553            University of Alaska, Anchorage

# %%
# retrieve school types from CSV file
school_types_df = pd.read_csv('../kaggle/salaries-by-college-type-id.csv', encoding='utf-8').iloc[:, 0:3]

# drop any rows with a missing college id
school_types_df = school_types_df[school_types_df['UNITID'].isna() == False]

# convert the college id to an integer
school_types_df = school_types_df.astype({ 'UNITID': int })

# rename the `UNITID` column to `college_id`
school_types_df.rename(columns={'UNITID': 'college_id', 'School Name': 'name', 'School Type': 'type'}, inplace=True)

# update school types of `Party` or `State` to `Public`
school_types_df.loc[school_types_df['type'].isin(['Party','State']), 'type'] = 'Public'

# drop duplicates
school_types_df.drop_duplicates(inplace=True)

# remove bad data
school_types_df = school_types_df.drop(school_types_df[(school_types_df['college_id']==233295) & (school_types_df['type']=='Public')].index)

# sort by `college_id`
school_types_df.sort_values(by='college_id', inplace=True)

# reset index
school_types_df.reset_index(drop=True,inplace=True)

print(school_types_df.shape)
school_types_df.head()
# Out:
# (248, 3)
#    college_id                                       name    type
# 0      100663  University of Alabama at Birmingham (UAB)  Public
# 1      100706  University of Alabama at Huntsville (UAH)  Public
# 2      100751          University of Alabama, Tuscaloosa  Public
# 3      100858                          Auburn University  Public
# 4      102553            University of Alaska, Anchorage  Public

# %%
school_types_df.groupby('type')['name'].count()
# Out:
# type
# Engineering      18
# Ivy League        8
# Liberal Arts     47
# Public          175
# Name: name, dtype: int64

# %%
test = schools_df.merge(school_types_df, on=['college_id','name'], how='left')

# %%
test.merge(college_names_df, on=['college_id'], how='left')[['college_id','type','schtype']]['type'].isna().value_counts()
# Out:
# False    247
# True      70
# Name: type, dtype: int64

# %%
# merge Kaggle schools data with Scorecard schools data
college_names_tbl = pd.merge(schools_df.merge(school_types_df, on=['college_id','name'], how='left'),
              college_names_df, on=['college_id'], how='left')

# replace missing Kaggle school type with Scorecard school type
college_names_tbl.type.fillna(college_names_tbl.schtype, inplace=True)

# delete unneeded columns
del college_names_tbl['schtype']
del college_names_tbl['name_y']

# rename `name` column
college_names_tbl.rename(columns={'name_x': 'name'}, inplace=True)

# set `college_id` as the index
college_names_tbl.set_index('college_id', inplace=True)

# display table
print(college_names_tbl.shape)
college_names_tbl.head()

# %%
# extract table to CSV file
#college_names_tbl.to_csv('../../resources/college_names.csv', sep=',', encoding='utf-8', mode='w')

# %%
# store table in database
college_names_tbl.to_sql(name='college_names', con=engine, if_exists='replace', index=True, method='multi')

# %%
# query database table
pd.read_sql('SELECT * FROM college_names', con=engine, index_col='college_id')
# Out:
#                                                          name                type                            website                    city state zipcode   latitude   longitude                                             region
# college_id
# 100663              University of Alabama at Birmingham (UAB)              Public                        www.uab.edu              Birmingham    AL   35294  33.505697  -86.799345  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 100706              University of Alabama at Huntsville (UAH)              Public                        www.uah.edu              Huntsville    AL   35899  34.724557  -86.640449  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 100751                      University of Alabama, Tuscaloosa              Public                        www.ua.edu/              Tuscaloosa    AL   35487  33.211875  -87.545978  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 100858                                      Auburn University              Public                     www.auburn.edu                  Auburn    AL   36849  32.599378  -85.488258  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 102553                        University of Alaska, Anchorage              Public                 www.uaa.alaska.edu               Anchorage    AK   99508  61.190163 -149.826190                  Far West (AK, CA, HI, NV, OR, WA)
# 104151                         Arizona State University (ASU)              Public                       www.asu.edu/                   Tempe    AZ   85287  33.417721 -111.934383                         Southwest (AZ, NM, OK, TX)
# 104179                                  University of Arizona              Public                    www.arizona.edu                  Tucson    AZ   85721  32.232672 -110.950815                         Southwest (AZ, NM, OK, TX)
# 106397                                 University of Arkansas              Public               https://www.uark.edu            Fayetteville    AR   72701  36.070009  -94.176981  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 106458                        Arkansas State University (ASU)              Public                    www.astate.edu/               Jonesboro    AR   72401  35.842388  -90.679988  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 106485              University of Arkansas - Monticello (UAM)              Public                    www.uamont.edu/              Monticello    AR   71656  33.590909  -91.811153  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 110404               California Institute of Technology (CIT)         Engineering                    www.caltech.edu                Pasadena    CA   91125  34.137349 -118.125878                  Far West (AK, CA, HI, NV, OR, WA)
# 110422                               Cal Poly San Luis Obispo              Public                        calpoly.edu         San Luis Obispo    CA   93407  35.299513 -120.657311                  Far West (AK, CA, HI, NV, OR, WA)
# 110495          California State University (CSU), Stanislaus              Public            https://www.csustan.edu                 Turlock    CA   95382  37.525770 -120.852511                  Far West (AK, CA, HI, NV, OR, WA)
# 110538               California State University (CSU), Chico              Public                   www.csuchico.edu                   Chico    CA   95929  39.729712 -121.844859                  Far West (AK, CA, HI, NV, OR, WA)
# 110547      California State University, Dominguez Hills (...              Public              https://www.csudh.edu                  Carson    CA   90747  33.864766 -118.255917                  Far West (AK, CA, HI, NV, OR, WA)
# 110565          California State University, Fullerton (CSUF)              Public                  www.fullerton.edu               Fullerton    CA   92831  33.881506 -117.885446                  Far West (AK, CA, HI, NV, OR, WA)
# 110574          California State University, East Bay (CSUEB)              Public                 www.csueastbay.edu                 Hayward    CA   94542  37.657694 -122.054135                  Far West (AK, CA, HI, NV, OR, WA)
# 110583        California State University, Long Beach (CSULB)              Public                      www.csulb.edu              Long Beach    CA   90840  33.782818 -118.112040                  Far West (AK, CA, HI, NV, OR, WA)
# 110608         California State University, Northridge (CSUN)              Public               https://www.csun.edu              Northridge    CA   91330  34.240126 -118.529319                  Far West (AK, CA, HI, NV, OR, WA)
# 110617         California State University, Sacramento (CSUS)              Public                       www.csus.edu              Sacramento    CA   95819  38.559415 -121.423549                  Far West (AK, CA, HI, NV, OR, WA)
# 110635                     University of California, Berkeley              Public                   www.berkeley.edu                Berkeley    CA   94720  37.871918 -122.260463                  Far West (AK, CA, HI, NV, OR, WA)
# 110644                        University of California, Davis              Public                    www.ucdavis.edu                   Davis    CA   95616  38.539667 -121.749567                  Far West (AK, CA, HI, NV, OR, WA)
# 110653                 University of California, Irvine (UCI)              Public                       www.uci.edu/                  Irvine    CA   92697  33.648434 -117.841248                  Far West (AK, CA, HI, NV, OR, WA)
# 110662         University of California at Los Angeles (UCLA)              Public                      www.ucla.edu/             Los Angeles    CA   90095  34.068892 -118.443901                  Far West (AK, CA, HI, NV, OR, WA)
# 110671              University of California, Riverside (UCR)              Public                        WWW.UCR.EDU               Riverside    CA   92521  33.972460 -117.327410                  Far West (AK, CA, HI, NV, OR, WA)
# 110680             University of California, San Diego (UCSD)              Public                       www.ucsd.edu                La Jolla    CA   92093  32.877749 -117.235866                  Far West (AK, CA, HI, NV, OR, WA)
# 110705         University of California, Santa Barbara (UCSB)              Public                       www.ucsb.edu           Santa Barbara    CA   93106  34.416297 -119.846426                  Far West (AK, CA, HI, NV, OR, WA)
# 110714            University of California, Santa Cruz (UCSC)              Public                      www.ucsc.edu/              Santa Cruz    CA   95064  36.995584 -122.058801                  Far West (AK, CA, HI, NV, OR, WA)
# 115409                                    Harvey Mudd College         Engineering                https://www.hmc.edu               Claremont    CA   91711  34.106515 -117.709837                  Far West (AK, CA, HI, NV, OR, WA)
# 115755                              Humboldt State University              Public                   www.humboldt.edu                  Arcata    CA   95521  40.877481 -124.078293                  Far West (AK, CA, HI, NV, OR, WA)
# 120254                                     Occidental College        Liberal Arts                https://www.oxy.edu             Los Angeles    CA   90041  34.127124 -118.210908                  Far West (AK, CA, HI, NV, OR, WA)
# 121345                                         Pomona College        Liberal Arts                     www.pomona.edu               Claremont    CA   91711  34.099027 -117.714556                  Far West (AK, CA, HI, NV, OR, WA)
# 122409                      San Diego State University (SDSU)              Public                       www.sdsu.edu               San Diego    CA   92182  32.775250 -117.071228                  Far West (AK, CA, HI, NV, OR, WA)
# 122597                  San Francisco State University (SFSU)              Public                       www.sfsu.edu           San Francisco    CA   94132  37.721224 -122.476799                  Far West (AK, CA, HI, NV, OR, WA)
# 122755                       San Jose State University (SJSU)              Public                       www.sjsu.edu                San Jose    CA   95192  37.336569 -121.880621                  Far West (AK, CA, HI, NV, OR, WA)
# 123961                University of Southern California (USC)  Private, Nonprofit                       www.usc.edu/             Los Angeles    CA   90089  34.021281 -118.284169                  Far West (AK, CA, HI, NV, OR, WA)
# 124292                                 Thomas Aquinas College        Liberal Arts      https://www.thomasaquinas.edu             Santa Paula    CA   93060  34.429009 -119.087141                  Far West (AK, CA, HI, NV, OR, WA)
# 126562                        University of Colorado - Denver              Public                  www.ucdenver.edu/                  Denver    CO   80217  39.745149 -104.837722               Rocky Mountains (CO, ID, MT, UT, WY)
# 126614                 University of Colorado - Boulder (UCB)              Public                   www.colorado.edu                 Boulder    CO   80309  40.008781 -105.270823               Rocky Mountains (CO, ID, MT, UT, WY)
# 126678                                  Colorado College (CC)        Liberal Arts            www.coloradocollege.edu        Colorado Springs    CO   80903  38.848860 -104.822697               Rocky Mountains (CO, ID, MT, UT, WY)
# 126775                               Colorado School of Mines         Engineering                      www.mines.edu                  Golden    CO   80401  39.751443 -105.223364               Rocky Mountains (CO, ID, MT, UT, WY)
# 126818                        Colorado State University (CSU)              Public                  www.colostate.edu            Fort Collins    CO   80523  40.574805 -105.080732               Rocky Mountains (CO, ID, MT, UT, WY)
# 127185                                     Fort Lewis College        Liberal Arts                     fortlewis.edu/                 Durango    CO   81301  37.275939 -107.867422               Rocky Mountains (CO, ID, MT, UT, WY)
# 127918                                       Regis University  Private, Nonprofit                     www.regis.edu/                  Denver    CO   80221  39.788175 -105.030756               Rocky Mountains (CO, ID, MT, UT, WY)
# 129020                      University of Connecticut (UConn)              Public                         uconn.edu/                  Storrs    CT   06269  41.809098  -72.249948               New England (CT, ME, MA, NH, RI, VT)
# 129941                                University of New Haven  Private, Nonprofit                   www.newhaven.edu              West Haven    CT   06516  41.291314  -72.961472               New England (CT, ME, MA, NH, RI, VT)
# 130226                                  Quinnipiac University  Private, Nonprofit                         www.qu.edu                  Hamden    CT   06518  41.418915  -72.894117               New England (CT, ME, MA, NH, RI, VT)
# 130253                                Sacred Heart University  Private, Nonprofit                www.sacredheart.edu               Fairfield    CT   06825  41.220893  -73.243332               New England (CT, ME, MA, NH, RI, VT)
# 130697          Wesleyan University (Middletown, Connecticut)        Liberal Arts                   www.wesleyan.edu              Middletown    CT   06459  41.554665  -72.657146               New England (CT, ME, MA, NH, RI, VT)
# 130794                                        Yale University          Ivy League               https://www.yale.edu               New Haven    CT   06520  41.311158  -72.926688               New England (CT, ME, MA, NH, RI, VT)
# 144740                                      DePaul University  Private, Nonprofit             https://www.depaul.edu                 Chicago    IL   60604  41.877618  -87.627240                   Great Lakes (IL, IN, MI, OH, WI)
# 145600                      University of Illinois at Chicago              Public                        www.uic.edu                 Chicago    IL   60607  41.871837  -87.650503                   Great Lakes (IL, IN, MI, OH, WI)
# 145637      University of Illinois at Urbana-Champaign (UIUC)              Public                  www.illinois.edu/               Champaign    IL   61820  40.104718  -88.229114                   Great Lakes (IL, IN, MI, OH, WI)
# 145725                 Illinois Institute of Technology (IIT)         Engineering                       web.iit.edu/                 Chicago    IL   60616  41.831300  -87.627321                   Great Lakes (IL, IN, MI, OH, WI)
# 145813                              Illinois State University              Public                 illinoisstate.edu/                  Normal    IL   61790  40.509403  -88.990058                   Great Lakes (IL, IN, MI, OH, WI)
# 147703                     Northern Illinois University (NIU)              Public                        www.niu.edu                  Dekalb    IL   60115  41.933869  -88.766428                   Great Lakes (IL, IN, MI, OH, WI)
# 147767                                Northwestern University  Private, Nonprofit               www.northwestern.edu                Evanston    IL   60208  42.050356  -87.679858                   Great Lakes (IL, IN, MI, OH, WI)
# 148335                            Robert Morris College (RMC)  Private, Nonprofit          https://robertmorris.edu/                 Chicago    IL   60605  41.876278  -87.627068                   Great Lakes (IL, IN, MI, OH, WI)
# 149222                Southern Illinois University Carbondale              Public                        www.siu.edu              Carbondale    IL   62901  37.714193  -89.217273                   Great Lakes (IL, IN, MI, OH, WI)
# 150136                            Ball State University (BSU)              Public                        www.bsu.edu                  Muncie    IN   47306  40.203431  -85.409043                   Great Lakes (IL, IN, MI, OH, WI)
# 150400                                      DePauw University        Liberal Arts                     www.depauw.edu             Greencastle    IN   46135  39.640904  -86.860363                   Great Lakes (IL, IN, MI, OH, WI)
# 151351                   Indiana University (IU), Bloomington              Public                   www.indiana.edu/             Bloomington    IN   47405  39.166090  -86.526559                   Great Lakes (IL, IN, MI, OH, WI)
# 151801                      Indiana Wesleyan University (IWU)  Private, Nonprofit             https://www.indwes.edu                  Marion    IN   46953  40.517937  -85.667503                   Great Lakes (IL, IN, MI, OH, WI)
# 152080                               University of Notre Dame  Private, Nonprofit                         www.nd.edu              Notre Dame    IN   46556  41.703058  -86.238959                   Great Lakes (IL, IN, MI, OH, WI)
# 153384                                       Grinnell College        Liberal Arts                   www.grinnell.edu                Grinnell    IA   50112  41.747952  -92.722094                Plains (IA, KS, MN, MO, NE, ND, SD)
# 153603                                  Iowa State University              Public                    www.iastate.edu                    Ames    IA   50011  42.026212  -93.648504                Plains (IA, KS, MN, MO, NE, ND, SD)
# 153658                                University of Iowa (UI)              Public                      www.uiowa.edu               Iowa City    IA   52242  41.661935  -91.536425                Plains (IA, KS, MN, MO, NE, ND, SD)
# 155317                                   University of Kansas              Public                     https://ku.edu                Lawrence    KS   66045  38.958549  -95.247567                Plains (IA, KS, MN, MO, NE, ND, SD)
# 155399                          Kansas State University (KSU)              Public                    www.k-state.edu               Manhattan    KS   66506  39.188648  -96.581077                Plains (IA, KS, MN, MO, NE, ND, SD)
# 155681                             Pittsburg State University              Public                  www.pittstate.edu               Pittsburg    KS   66762  37.392071  -94.702473                Plains (IA, KS, MN, MO, NE, ND, SD)
# 157085                            University of Kentucky (UK)              Public                        www.uky.edu               Lexington    KY   40506  38.038911  -84.504747  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
#
# 166629          University of Massachusetts (UMass) - Amherst              Public                      www.umass.edu                 Amherst    MA   01003  42.385999  -72.526728               New England (CT, ME, MA, NH, RI, VT)
# 166638           University of Massachusetts (UMass) - Boston              Public                        www.umb.edu                  Boston    MA   02125  42.312881  -71.036865               New England (CT, ME, MA, NH, RI, VT)
# 166683            Massachusetts Institute of Technology (MIT)         Engineering                       web.mit.edu/               Cambridge    MA   02139  42.359243  -71.093226               New England (CT, ME, MA, NH, RI, VT)
# 166939                                  Mount Holyoke College        Liberal Arts          https://www.mtholyoke.edu            South Hadley    MA   01075  42.256838  -72.575511               New England (CT, ME, MA, NH, RI, VT)
# 167358                                Northeastern University  Private, Nonprofit               www.northeastern.edu                  Boston    MA   02115  42.339992  -71.088782               New England (CT, ME, MA, NH, RI, VT)
# 167835                                          Smith College        Liberal Arts                      www.smith.edu             Northampton    MA   01063  42.318111  -72.638097               New England (CT, ME, MA, NH, RI, VT)
# 167987        University of Massachusetts (UMass) - Dartmouth              Public                     www.umassd.edu         North Dartmouth    MA   02747  41.628690  -71.004552               New England (CT, ME, MA, NH, RI, VT)
# 168005                                     Suffolk University  Private, Nonprofit                    www.suffolk.edu                  Boston    MA   02108  42.357945  -71.060917               New England (CT, ME, MA, NH, RI, VT)
# 168218                                      Wellesley College        Liberal Arts                  www.wellesley.edu               Wellesley    MA   02481  42.291554  -71.306605               New England (CT, ME, MA, NH, RI, VT)
# 168227                      Wentworth Institute of Technology         Engineering                    https://WIT.EDU                  Boston    MA   02115  42.336632  -71.094983               New England (CT, ME, MA, NH, RI, VT)
# 168342                                       Williams College        Liberal Arts           https://www.williams.edu            Williamstown    MA   01267  42.712725  -73.203132               New England (CT, ME, MA, NH, RI, VT)
# 168421                  Worcester Polytechnic Institute (WPI)         Engineering               https://www.wpi.edu/               Worcester    MA   01609  42.274853  -71.808339               New England (CT, ME, MA, NH, RI, VT)
# 169479                                   Davenport University  Private, Nonprofit                  www.davenport.edu            Grand Rapids    MI   49512  42.850013  -85.533519                   Great Lakes (IL, IN, MI, OH, WI)
# 169798                            Eastern Michigan University              Public                      www.emich.edu               Ypsilanti    MI   48197  42.246940  -83.622501                   Great Lakes (IL, IN, MI, OH, WI)
# 170976                                 University of Michigan              Public                      www.umich.edu               Ann Arbor    MI   48109  42.275921  -83.742769                   Great Lakes (IL, IN, MI, OH, WI)
# 171100                        Michigan State University (MSU)              Public                https://www.msu.edu            East Lansing    MI   48824  42.732120  -84.476111                   Great Lakes (IL, IN, MI, OH, WI)
# 172644                                 Wayne State University              Public                      www.wayne.edu                 Detroit    MI   48202  42.358994  -83.068998                   Great Lakes (IL, IN, MI, OH, WI)
# 172699                      Western Michigan University (WMU)              Public                 https://wmich.edu/               Kalamazoo    MI   49008  42.282194  -85.613759                   Great Lakes (IL, IN, MI, OH, WI)
# 173258                                       Carleton College        Liberal Arts                   www.carleton.edu              Northfield    MN   55057  44.462318  -93.154666                Plains (IA, KS, MN, MO, NE, ND, SD)
# 173647                              Gustavus Adolphus College        Liberal Arts                      gustavus.edu/             Saint Peter    MN   56082  44.323626  -93.972196                Plains (IA, KS, MN, MO, NE, ND, SD)
# 173920                   Minnesota State University - Mankato              Public          https://mankato.mnsu.edu/                 Mankato    MN   56001  44.146712  -93.999450                Plains (IA, KS, MN, MO, NE, ND, SD)
# 174066                                University of Minnesota              Public        https://twin-cities.umn.edu             Minneapolis    MN   55455  44.972851  -93.235464                Plains (IA, KS, MN, MO, NE, ND, SD)
# 174783                             St. Cloud State University              Public               www.stcloudstate.edu             Saint Cloud    MN   56301  45.553227  -94.152657                Plains (IA, KS, MN, MO, NE, ND, SD)
# 174844                                       St. Olaf College        Liberal Arts                      wp.stolaf.edu              Northfield    MN   55057  44.461529  -93.182039                Plains (IA, KS, MN, MO, NE, ND, SD)
# 176017                              University of Mississippi              Public                    www.olemiss.edu              University    MS   38677  34.365529  -89.537434  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 176053                                    Mississippi College  Private, Nonprofit                         www.mc.edu                 Clinton    MS   39058  32.335515  -90.329821  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 176080                     Mississippi State University (MSU)              Public                    www.msstate.edu       Mississippi State    MS   39762  33.454852  -88.790139  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 178396                      University of Missouri - Columbia              Public                      missouri.edu/                Columbia    MO   65211  38.945310  -92.328843                Plains (IA, KS, MN, MO, NE, ND, SD)
# 178402            University of Missouri - Kansas City (UMKC)              Public              https://www.umkc.edu/             Kansas City    MO   64110  39.034179  -94.582141                Plains (IA, KS, MN, MO, NE, ND, SD)
# 178411                   University of Missouri - Rolla (UMR)              Public                       www.mst.edu/                   Rolla    MO   65409  37.953426  -91.775583                Plains (IA, KS, MN, MO, NE, ND, SD)
# 178420              University of Missouri - St. Louis (UMSL)              Public              https://www.umsl.edu/             Saint Louis    MO   63121  38.710312  -90.311091                Plains (IA, KS, MN, MO, NE, ND, SD)
# 178721                                        Park University  Private, Nonprofit                       www.park.edu               Parkville    MO   64152  39.189256  -94.679041                Plains (IA, KS, MN, MO, NE, ND, SD)
# 179566                        Missouri State University (MSU)              Public              www.missouristate.edu             Springfield    MO   65897  37.199258  -93.281281                Plains (IA, KS, MN, MO, NE, ND, SD)
# 180179                    Montana State University - Billings              Public                www.msubillings.edu                Billings    MT   59101  45.796896 -108.523009               Rocky Mountains (CO, ID, MT, UT, WY)
# 180461                     Montana State University - Bozeman              Public                   www.montana.edu/                 Bozeman    MT   59717  45.666726 -111.048812               Rocky Mountains (CO, ID, MT, UT, WY)
# 180692                                  University of Montana              Public                   w.umwestern.edu/                  Dillon    MT   59725  45.208306 -112.639264               Rocky Mountains (CO, ID, MT, UT, WY)
# 181394                        University of Nebraska at Omaha              Public            https://www.unomaha.edu                   Omaha    NE   68182  41.258769  -96.008516                Plains (IA, KS, MN, MO, NE, ND, SD)
# 181464                                 University of Nebraska              Public                       www.unl.edu/                 Lincoln    NE   68588  40.817598  -96.700508                Plains (IA, KS, MN, MO, NE, ND, SD)
# 182281                 University of Nevada, Las Vegas (UNLV)              Public                      www.unlv.edu/               Las Vegas    NV   89154  36.106047 -115.138462                  Far West (AK, CA, HI, NV, OR, WA)
Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 219046                           Black Hills State University              Public                       www.bhsu.edu               Spearfish    SD   57799  44.494889 -103.870966                Plains (IA, KS, MN, MO, NE, ND, SD)
# 219347              South Dakota School of Mines & Technology         Engineering                      www.sdsmt.edu              Rapid City    SD   57701  44.075439 -103.205753                Plains (IA, KS, MN, MO, NE, ND, SD)
# 219356                   South Dakota State University (SDSU)              Public           https://www.sdstate.edu/               Brookings    SD   57007  44.317485  -96.782139                Plains (IA, KS, MN, MO, NE, ND, SD)
# 219602                           Austin Peay State University              Public                       www.apsu.edu             Clarksville    TN   37044  36.533319  -87.354081  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 220613                         Lee University (Cleveland, TN)  Private, Nonprofit              www.leeuniversity.edu               Cleveland    TN   37311  35.166019  -84.871399  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 220862                         University of Memphis (U of M)              Public                    www.memphis.edu                 Memphis    TN   38152  35.118878  -89.938068  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 221759                                University of Tennessee              Public                        www.utk.edu               Knoxville    TN   37996  35.952082  -83.925852  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 221847                     Tennessee Technological University         Engineering                     www.tntech.edu              Cookeville    TN   38505  36.174754  -85.504039  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 221953                                       Tusculum College  Private, Nonprofit                   www.tusculum.edu             Greeneville    TN   37743  36.172435  -82.760818  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 221999                                  Vanderbilt University  Private, Nonprofit                 www.vanderbilt.edu               Nashville    TN   37240  36.146590  -86.803369  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 223232                                      Baylor University  Private, Nonprofit                     www.baylor.edu                    Waco    TX   76798  31.546872  -97.121041                         Southwest (AZ, NM, OK, TX)
# 224226                              Dallas Baptist University  Private, Nonprofit                https://www.dbu.edu                  Dallas    TX   75211  32.710017  -96.947006                         Southwest (AZ, NM, OK, TX)
# 225511                             University of Houston (UH)              Public                        www.uh.edu/                 Houston    TX   77204  29.720393  -95.343537                         Southwest (AZ, NM, OK, TX)
# 226091                                       Lamar University              Public                      www.lamar.edu                Beaumont    TX   77705  30.042738  -94.072244                         Southwest (AZ, NM, OK, TX)
# 226231                                  LeTourneau University  Private, Nonprofit                       www.letu.edu                Longview    TX   75602  32.466320  -94.726394                         Southwest (AZ, NM, OK, TX)
# 227757                                        Rice University  Private, Nonprofit                       www.rice.edu                 Houston    TX   77005  29.717897  -95.402035                         Southwest (AZ, NM, OK, TX)
# 228529                        Tarleton State University (TSU)              Public                   www.tarleton.edu            Stephenville    TX   76401  32.214988  -98.214866                         Southwest (AZ, NM, OK, TX)
# 228723                                   Texas A&M University              Public                       www.tamu.edu         College Station    TX   77843  30.618726  -96.336475                         Southwest (AZ, NM, OK, TX)
# 228769                 University of Texas at Arlington (UTA)              Public                        WWW.UTA.EDU               Arlington    TX   76013  32.729718  -97.112960                         Southwest (AZ, NM, OK, TX)
# 228778                      University of Texas (UT) - Austin              Public                     www.utexas.edu                  Austin    TX   78712  30.282825  -97.738273                         Southwest (AZ, NM, OK, TX)
# 228796                  University of Texas at El Paso (UTEP)              Public                       www.utep.edu                 El Paso    TX   79968  31.770150 -106.504098                         Southwest (AZ, NM, OK, TX)
# 228875                       Texas Christian University (TCU)  Private, Nonprofit                       www.tcu.edu/              Fort Worth    TX   76129  32.709610  -97.364758                         Southwest (AZ, NM, OK, TX)
# 229027              University of Texas at San Antonio (UTSA)              Public                      www.utsa.edu/             San Antonio    TX   78249  29.583709  -98.620657                         Southwest (AZ, NM, OK, TX)
Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 238032                         West Virginia University (WVU)              Public                        www.wvu.edu              Morgantown    WV   26506  39.634371  -79.954391  Southeast (AL, AR, FL, GA, KY, LA, MS, NC, SC,...
# 239105                                   Marquette University  Private, Nonprofit                  www.marquette.edu               Milwaukee    WI   53233  43.039030  -87.927961                   Great Lakes (IL, IN, MI, OH, WI)
# 240189              University of Wisconsin (UW) - Whitewater              Public                        www.uww.edu              Whitewater    WI   53190  42.835563  -88.742368                   Great Lakes (IL, IN, MI, OH, WI)
# 240268              University of Wisconsin (UW) - Eau Claire              Public                       www.uwec.edu              Eau Claire    WI   54701  44.798284  -91.501906                   Great Lakes (IL, IN, MI, OH, WI)
# 240277               University of Wisconsin (UW) - Green Bay              Public                       www.uwgb.edu               Green Bay    WI   54311  44.532298  -87.919973                   Great Lakes (IL, IN, MI, OH, WI)
# 240329               University of Wisconsin (UW) - La Crosse              Public                      www.uwlax.edu               La Crosse    WI   54601  43.815680  -91.231860                   Great Lakes (IL, IN, MI, OH, WI)
# 240365                 University of Wisconsin (UW) - Oshkosh              Public                      www.uwosh.edu                 Oshkosh    WI   54901  44.026206  -88.549369                   Great Lakes (IL, IN, MI, OH, WI)
# 240374                University of Wisconsin (UW) - Parkside              Public                https://www.uwp.edu                 Kenosha    WI   53144  42.647718  -87.855231                   Great Lakes (IL, IN, MI, OH, WI)
# 240417                   University of Wisconsin (UW) - Stout              Public                    www.uwstout.edu               Menomonie    WI   54751  44.873187  -91.926653                   Great Lakes (IL, IN, MI, OH, WI)
# 240444                 University of Wisconsin (UW) - Madison              Public                       www.wisc.edu                 Madison    WI   53706  43.075409  -89.404098                   Great Lakes (IL, IN, MI, OH, WI)
# 240453               University of Wisconsin (UW) - Milwaukee              Public                            uwm.edu               Milwaukee    WI   53211  43.076848  -87.880488                   Great Lakes (IL, IN, MI, OH, WI)
# 240462             University of Wisconsin (UW) - Platteville              Public                    www.uwplatt.edu             Platteville    WI   53818  42.733451  -90.486220                   Great Lakes (IL, IN, MI, OH, WI)
# 240480           University of Wisconsin (UW) - Stevens Point              Public               https://www.uwsp.edu           Stevens Point    WI   54481  44.529582  -89.570934                   Great Lakes (IL, IN, MI, OH, WI)
# 240727                             University of Wyoming (UW)              Public                       www.uwyo.edu                 Laramie    WY   82071  41.311773 -105.579310               Rocky Mountains (CO, ID, MT, UT, WY)
# 243744                                    Stanford University  Private, Nonprofit                  www.stanford.edu/                Stanford    CA   94305  37.429434 -122.167359                  Far West (AK, CA, HI, NV, OR, WA)
# 243780                                      Purdue University              Public                     www.purdue.edu          West Lafayette    IN   47907  40.428206  -86.914435                   Great Lakes (IL, IN, MI, OH, WI)
