# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
collegetype_df = pd.read_csv("salaries-by-college-type-id.csv")
collegetype_df
# Out:
#        UNITID                                   School Name  School Type  \
# 0    166683.0   Massachusetts Institute of Technology (MIT)  Engineering
# 1    110404.0      California Institute of Technology (CIT)  Engineering
# 2    115409.0                           Harvey Mudd College  Engineering
# 3         NaN  Polytechnic University of New York, Brooklyn  Engineering
# 4    190372.0                                  Cooper Union  Engineering
# ..        ...                                           ...          ...
# 264  219602.0                  Austin Peay State University        State
# 265  155681.0                    Pittsburg State University        State
# 266  230603.0                      Southern Utah University        State
# 267  180179.0           Montana State University - Billings        State
# 268  219046.0                  Black Hills State University        State
#
#     Starting Median Salary Mid-Career Median Salary  \
# ...

# %%
collegetype_df['School Name'].unique()
# Out:
# array(['Massachusetts Institute of Technology (MIT)',
#        'California Institute of Technology (CIT)', 'Harvey Mudd College',
#        'Polytechnic University of New York, Brooklyn', 'Cooper Union',
#        'Worcester Polytechnic Institute (WPI)',
#        'Carnegie Mellon University (CMU)',
#        'Rensselaer Polytechnic Institute (RPI)',
#        'Georgia Institute of Technology', 'Colorado School of Mines',
#        'Stevens Institute of Technology',
#        'Illinois Institute of Technology (IIT)',
#        'Wentworth Institute of Technology',
#        'Virginia Polytechnic Institute and State University (Virginia Tech)',
#        'South Dakota School of Mines & Technology',
#        'New Mexico Institute of Mining and Technology (New Mexico Tech)',
#        'Rochester Institute of Technology (RIT)',
#        'Embry-Riddle Aeronautical University (ERAU)',
#        'Tennessee Technological University',
#        'University of Illinois at Urbana-Champaign (UIUC)',
# ...

# %%
collegetype_df['School Type'].unique()
# Out:
# array(['Engineering', 'Party', 'Liberal Arts', 'Ivy League', 'State'],
#       dtype=object)

# %%
partyschools_df = collegetype_df[collegetype_df['School Type'] == 'Party']
partyschools_df
# Out:
#       UNITID                                        School Name School Type  \
# 19  145637.0  University of Illinois at Urbana-Champaign (UIUC)       Party
# 20  163286.0               University of Maryland, College Park       Party
# 21  110705.0     University of California, Santa Barbara (UCSB)       Party
# 22  228778.0                  University of Texas (UT) - Austin       Party
# 23  196060.0      State University of New York (SUNY) at Albany       Party
# 24  134130.0                         University of Florida (UF)       Party
# 25  159391.0                   Louisiana State University (LSU)       Party
# 26  139959.0                        University of Georgia (UGA)       Party
# 27  214777.0                Pennsylvania State University (PSU)       Party
# 28  104151.0                     Arizona State University (ASU)       Party
# 29  151351.0               Indiana University (IU), Bloomington       Party
# ...

# %% [markdown]
# # Connect to local database

# %%
#rds_connection_string = "<insert user name>:<insert password>@localhost:5432/customer_db"
rds_connection_string = "postgres:postgres@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# # Use pandas to load csv converted DataFrame into database

# %%
collegetype_df.head(10)
# Out:
#      UNITID                                   School Name  School Type  \
# 0  166683.0   Massachusetts Institute of Technology (MIT)  Engineering
# 1  110404.0      California Institute of Technology (CIT)  Engineering
# 2  115409.0                           Harvey Mudd College  Engineering
# 3       NaN  Polytechnic University of New York, Brooklyn  Engineering
# 4  190372.0                                  Cooper Union  Engineering
# 5  168421.0         Worcester Polytechnic Institute (WPI)  Engineering
# 6  211440.0              Carnegie Mellon University (CMU)  Engineering
# 7  194824.0        Rensselaer Polytechnic Institute (RPI)  Engineering
# 8  139755.0               Georgia Institute of Technology  Engineering
# 9  126775.0                      Colorado School of Mines  Engineering
#
#   Starting Median Salary Mid-Career Median Salary  \
# 0            $72,200.00              $126,000.00
# 1            $75,500.00              $123,000.00
# ...

# %%
if_exists_param = 'replace'

collegetype_df.to_sql(name='customer_name', con=engine, if_exists=if_exists_param, index=False)
